# %% [markdown]
# # Import

# %%
# import modules
import pandas as pd
import numpy as np
import spotipy

# jupyter notebook full-width display
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# pandas formatting
pd.set_option('display.float_format', '{:_.3f}'.format)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 200)
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Import Data
# from: Kevin 820 Data Import and Clean.ipynb

# %%
desired_formatting = [
    'id', 'song', 'artist',
    'acousticness', 'danceability', 'duration_ms', 'energy', 
    'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 
    'speechiness', 'tempo', 'time_signature', 'valence'
]

desired_formatting_timeseries = [
    'date', 
    'id', 'song', 'artist',
    'rank', 'last-week', 'peak-rank', 'weeks-on-board',
    'acousticness', 'danceability', 'duration_ms', 'energy', 
    'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 
    'speechiness', 'tempo', 'time_signature', 'valence'
]

# datatypes to reduce file sizes and increase calculation speed
# Int8 and float16 is enough to store data, but error occur with descriptive stats
# Try Int16 and float32
dtypes = {
    'key': 'Int16', 'mode': 'Int16', 'time_signature': 'Int16', 'tempo': 'float32', 
    'acousticness': 'float32', 'danceability': 'float32', 'duration_ms': 'Int32', 
    'energy': 'float32', 'instrumentalness': 'float32', 'liveness': 'float32', 
    'loudness': 'float32', 'speechiness': 'float32', 'valence': 'float32'
} 

dtypes_timeseries = {
    'rank': 'Int16', 'last-week': 'Int16', 'peak-rank': 'Int16', 'weeks-on-board': 'Int16'
}

# all songs with audio features (combined from 3 sources)
df_10M = pd.read_csv('every_song_with_data.csv', dtype=dtypes)
df_10M = df_10M[desired_formatting]

# all Billboard 100 lists, audio features included where possible
df_B100 = pd.read_csv(
    'all_audio_features_billboard_100.csv', 
    dtype={**dtypes, **dtypes_timeseries}
)
df_B100 = df_B100[desired_formatting_timeseries]
df_B100['date'] = pd.to_datetime(df_B100['date'])

# all unique songs from the Billboard 100 lists, audio features included where possible
df_B100_songs = pd.read_csv('all_audio_features_billboard_100_songs.csv', dtype=dtypes)
df_B100_songs = df_B100_songs[desired_formatting]

# %%
# No errors with Int16 and float32

df_10M.describe().loc['mean':'max'].T
# Out:
#                            mean               std            min  \
# acousticness       0.4213421047      0.3735598326   0.0000000000
# danceability       0.5275657177      0.1904722154   0.0000000000
# duration_ms       97.4084946090 159341.5907809948   0.0000000000
# energy             0.5446365476      0.2815802395   0.0000000000
# instrumentalness   0.2578041255      0.3736388981   0.0000000000
# key                5.2371749580      3.5424904071   0.0000000000
# liveness           0.2096685618      0.1800441295   0.0000000000
# loudness         -10.9673919678      6.3175172806 -60.0000000000
# mode               0.6610928813      0.4733382585   0.0000000000
# speechiness        0.0977755114      0.1350511312   0.0000000000
# tempo            118.7850875854     30.8315696716   0.0000000000
# time_signature     3.8395182072      0.5665857075   0.0000000000
# valence            0.4737367332      0.2781454027   0.0000000000
#
#                                25%               50%               75%  \
# acousticness          0.0335000008      0.3359999955      0.8169999719
# danceability          0.3959999979      0.5450000167      0.6759999990
# duration_ms      169600.0000000000 216933.0000000000 275080.0000000000
# energy                0.3100000024      0.5669999719      0.7889999747
# instrumentalness      0.0000013200      0.0020999999      0.6449999809
# key                   2.0000000000      5.0000000000      8.0000000000
# liveness              0.0964000002      0.1289999932      0.2619999945
# loudness            -13.6750001907     -9.1960000992     -6.3979997635
# mode                  0.0000000000      1.0000000000      1.0000000000
# speechiness           0.0357999988      0.0469999984      0.0821999982
# tempo                95.0800018311    118.9499969482    137.4499969482
# time_signature        4.0000000000      4.0000000000      4.0000000000
# valence               0.2339999974      0.4679999948      0.7080000043
#
#                                  max
# acousticness            0.9959999919
# danceability            1.0000000000
# duration_ms      19672058.0000000000
# energy                  1.0000000000
# instrumentalness        1.0000000000
# key                    11.0000000000
# liveness                1.0000000000
# loudness                7.2340002060
# mode                    1.0000000000
# speechiness             0.9739999771
# tempo                 249.9869995117
# time_signature          5.0000000000
# valence                 1.0000000000

# %% [markdown]
# # SIGNIFICANT FIGURES CHECK

# %%
# 3 sig figs of accuracy is adequate for audio features
# everything beyond that appears to be rounding error, and shouldn't affect calculations
# float16 is adequate to store data (but float32 is required for statistical calculations)

df_10M.query('id=="33ZXjLCpiINn8eQIDYEPTD"')
# Out:
#                            id                song     artist  acousticness  \
# 22205  33ZXjLCpiINn8eQIDYEPTD  Shook Ones, Pt. II  Mobb Deep  0.0146000003
#
#        danceability  duration_ms       energy  instrumentalness  key  \
# 22205  0.7630000114       325506 0.7860000134      0.0114000002   10
#
#           liveness      loudness  mode  speechiness         tempo  \
# 22205 0.0816999972 -6.4720001221     0 0.2290000021 93.8570022583
#
#        time_signature      valence
# 22205               4 0.5040000081

# %%
df_10M.query('id=="2jKoVlU7VAmExKJ1Jh3w9P"')
# Out:
#                             id                                        song  \
# 392848  2jKoVlU7VAmExKJ1Jh3w9P  Alkaholik (feat. Erik Sermon, J Ro & Tash)
#
#        artist  acousticness  danceability  duration_ms       energy  \
# 392848   Tash  0.1800000072  0.8930000067       219160 0.5139999986
#
#         instrumentalness  key     liveness      loudness  mode  speechiness  \
# 392848      0.0000000000   11 0.0595999993 -5.0799999237     1 0.2829999924
#
#                tempo  time_signature      valence
# 392848 95.8479995728               4 0.7870000005

# %%
df_10M.query('id=="7iL6o9tox1zgHpKUfh9vuC"')
# Out:
#                            id        song   artist  acousticness  \
# 22198  7iL6o9tox1zgHpKUfh9vuC  In Da Club  50 Cent  0.2549999952
#
#        danceability  duration_ms       energy  instrumentalness  key  \
# 22198  0.8989999890       193466 0.7129999995      0.0000000000    6
#
#           liveness      loudness  mode  speechiness         tempo  \
# 22198 0.0707999989 -2.7520000935     0 0.3659999967 90.0510025024
#
#        time_signature      valence
# 22198               4 0.7770000100

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Save as Parquet Format

# %%
# Save Data
df_10M.to_parquet('df_10M.parquet')
df_B100.to_parquet('df_B100.parquet')
df_B100_songs.to_parquet('df_B100_songs.parquet')

# %% [markdown]
# # Import Release Date

# %% [markdown]
# ### Reimport Data First

# %%
# all songs with audio features (combined from 3 sources)
df_10M = pd.read_parquet('df_10M.parquet')

# all Billboard 100 lists, audio features included where possible
df_B100 = pd.read_parquet('df_B100.parquet')

# all unique songs from the Billboard 100 lists, audio features included where possible
df_B100_songs = pd.read_parquet('df_B100_songs.parquet')

# all unique songs from the Billboard 100 lists, only songs with audio features included
df_B100_songs_AF = df_B100_songs.dropna().copy().reset_index(drop=True)

# %% [markdown]
# ### Spotify API (Hot 100 songs)
#
# ##### get a temporary authorization token from: https://developer.spotify.com/console/get-search-item

# %%
# input the temporary token
TEMP_TOKEN = input('Enter token: ')

# create a spotify object
spotify = spotipy.Spotify(auth=TEMP_TOKEN)
# Out:
# Enter token: BQCoJoa0yB7VAVrWrWQs7pnv8cWO2bb8XevJRVCPKAkPD6eGKANwzZWQKnT2UzXPApJbSpIJpx9rVPD0Y8ICr7i4Uihy6mCL6nQ78lsMKtMHr24psF5ZPYdZfBxbt8A33lN_748f7xuLAwBjy64_VNy2UKXa6HQ8L2FtFmp8oV38

# %%
def get_release_date(track_id):
    track_info = spotify.track(track_id)
    return track_info['album']['release_date']

# %%
try: # only do this once, if row exists, just show head()
    display(df_B100_songs['release_date'].head())
except:
    df_B100_songs['release_date'] = ''
# Out:
# 0          1965
# 1    1965-01-01
# 2          1965
# 3           NaN
# 4    1996-12-31
# Name: release_date, dtype: object

# %%
# start over at
start_over_at = 30000

# populate df_billboard_songs with ids, where available
for i, row in df_B100_songs.iterrows():
    
    # start over at
    if i < start_over_at-1:
        continue
    
    # show status update
    if i%100 == 0:
        print(i, end='  ')
    if i%1000 == 0:
        print()
        
    # start over where we finished (don't overwrite known release_dates)
    # np.nan != '' should work
    if row['release_date'] != '':  
        continue
    
    # if id nan, release_date is unknown
    if pd.isna(row['id']):  # if id is not known  
        df_B100_songs.loc[i, 'release_date'] = np.nan
    else:
        df_B100_songs.loc[i, 'release_date'] = get_release_date(row['id'])
    
        # save every 1000 rows, if new
        if i%1000 == 0:
            df_B100_songs.to_parquet('df_B100_songs_TEMP.parquet')
        
# save final dataframe
df_B100_songs.to_parquet('df_B100_songs.parquet')
# Out:
# 27800  27900  28000
# 28100  28200  28300  28400  28500  28600  28700  28800  28900  29000
# 29100  29200  29300  29400  29500  29600

# %% [markdown]
# ### From SQL (10M songs)

# %%
sql_release_dates = pd.read_csv('release_dates_from_sql.csv')

# %%
# replace anything older than billboard with arbitrary date, to remove out of bound error
# min 
min_date, replace_date = -360200000000, -2208988800000
df_B100.date.min(), pd.to_datetime(min_date, unit='ms', origin='unix'), pd.to_datetime(replace_date, unit='ms', origin='unix')
# Out:
# (Timestamp('1958-08-04 00:00:00'),
#  Timestamp('1958-08-03 00:26:40'),
#  Timestamp('1900-01-01 00:00:00'))

# %%
# replace dates
sql_release_dates.loc[sql_release_dates.release_date < min_date, 'release_date'] = replace_date

# change to datetime format
sql_release_dates['release_date'] = pd.to_datetime(sql_release_dates['release_date'], unit='ms', origin='unix')

# %%
sql_release_dates.head()
# Out:
#                        id   release_date
# 0  2g8HN35AnVGIk7B8yMucww   779414400000
# 1  4E5IFAXCob6QqZaJMTw5YN  1041379200000
# 2  1gSt2UlC7mtRtJIc5zqKWn  1167609600000
# 3  67IvfvAMYQzJEeHopvwMMW   940291200000
# 4  2I9foKseoFQh07p6sD2voE  1044489600000

# %%
pd.merge(df_10M.head(), sql_release_dates, how='left', on='id')[['id', 'song', 'artist', 'release_date']]
# Out:
#                        id                                       song  \
# 0  7DZsH0df0GuULl0FGwXMfd                                      Misty
# 1  11Aldbvo6UCcVhBzv4oUdw                           What Now My Love
# 2  4KRLWRl1bFjnXhY5MgZWrM  May The Bird Of Paradise Fly Up Your Nose
# 3  5r96TaQquRrlo3Ym3ZlSL2                             Amish Paradise
# 4  1gloYGAZI6eHp6MEPjLuL3                             Canadian Idiot
#
#                    artist release_date
# 0         "Groove" Holmes   1965-01-01
# 1         "Groove" Holmes          NaT
# 2  "Little" Jimmy Dickens   1965-01-01
# 3     "Weird Al" Yankovic   1996-12-31
# 4     "Weird Al" Yankovic   2006-09-26

# %%
sql_release_dates[sql_release_dates.id == '11Aldbvo6UCcVhBzv4oUdw']
# Out:
# Empty DataFrame
# Columns: [id, release_date]
# Index: []

# %% [markdown]
# ### at least one track missing
# SQL query also null
#
#     SELECT * FROM tracks
#     WHERE id = '11Aldbvo6UCcVhBzv4oUdw'
#
# ![image.png](attachment:image.png)

# %%
df_10M[df_10M.id == '11Aldbvo6UCcVhBzv4oUdw']
# Out:
#                        id              song           artist  acousticness  \
# 1  11Aldbvo6UCcVhBzv4oUdw  What Now My Love  "Groove" Holmes         0.648
#
#    danceability  duration_ms  energy  instrumentalness  key  liveness  \
# 1         0.562       327560   0.573             0.314    7     0.056
#
#    loudness  mode  speechiness  tempo  time_signature  valence
# 1   -10.972     1        0.034 91.845               4    0.810

# %%
# did it have a leading zero?
sql_artist_id_by_track[sql_artist_id_by_track.artist_id=='02KuW0NIYd0JlYMCuk8C47']
# Out:
#                         track_id               artist_id
# 7741553   0KUuFwRWipiJl2w1mSYOSv  02KuW0NIYd0JlYMCuk8C47
# 7741557   6zRZ11EFUVpwOsYMBZwltv  02KuW0NIYd0JlYMCuk8C47
# 7877488   1fHwelRjKPEZS2iVerm8a4  02KuW0NIYd0JlYMCuk8C47
# 8199471   60J3ATd36b9aymF7MQePCI  02KuW0NIYd0JlYMCuk8C47
# 10024861  7qwarbGZ5uNNPyzAQCcxfL  02KuW0NIYd0JlYMCuk8C47

# %%
# nope, it wasn't in the 9M songs database, it was from the other dataset
df_B100_songs[df_B100_songs.id=='11Aldbvo6UCcVhBzv4oUdw']
# Out:
#                        id              song           artist  acousticness  \
# 1  11Aldbvo6UCcVhBzv4oUdw  What Now My Love  "Groove" Holmes         0.648
#
#    danceability  duration_ms  energy  instrumentalness  key  liveness  \
# 1         0.562       327560   0.573             0.314    7     0.056
#
#    loudness  mode  speechiness  tempo  time_signature  valence release_date
# 1   -10.972     1        0.034 91.845               4    0.810   1965-01-01

# %% [markdown]
# ### that missing date is legit
# just drop missing rows when time plotting
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Import Genre

# %% [markdown]
# ### Reimport Data First

# %%
# all songs with audio features (combined from 3 sources)
df_10M = pd.read_parquet('df_10M.parquet')

# all Billboard 100 lists, audio features included where possible
df_B100 = pd.read_parquet('df_B100.parquet')

# all unique songs from the Billboard 100 lists, audio features included where possible
df_B100_songs = pd.read_parquet('df_B100_songs.parquet')

# all unique songs from the Billboard 100 lists, only songs with audio features included
df_B100_songs_AF = df_B100_songs.dropna().copy().reset_index(drop=True)

# %%
# genre info from sql
df_artist_genres_10M = pd.read_csv('artist_genre_sql.csv')
df_sorted_list_of_genres = pd.read_csv('sorted_list_of_genres.csv')
sql_artist_id_by_track = pd.read_csv('sql_artist_id_by_track.csv')

# %%
df_sorted_list_of_genres.head()
# Out:
#         genre_id  counts
# 0      dance pop     591
# 1            pop     585
# 2           rock     579
# 3  electro house     572
# 4          latin     515

# %% [markdown]
# ### Spotify API (Hot 100 songs)
#
# ##### get a temporary authorization token from: https://developer.spotify.com/console/get-search-item

# %%
# input the temporary token
TEMP_TOKEN = input('Enter token: ')

# create a spotify object
spotify = spotipy.Spotify(auth=TEMP_TOKEN)
# Out:
# Enter token: BQB1h9QZsWb41EeaoLbiBcsbTyEDl6C5Y7p-gs6agR6RtyY9lLYzWu-I1cjvmwardmdwSh3AwptFlq2OuV0fqirkoofKQiaCIZRV48d8Z6tD5qtE_hJERziTA7AY9nBbS1lqFH5bvGzqJGTk87QhNsdH-25oMWpJ6f-pfKPvZ3aY

# %%
# HELPER FUNCTIONS

def get_artist_id_by_track(track_id):
    track_info = spotify.track(track_id)
    return track_info['artists'][0]['id']

def get_genre_by_artist(artist_id):
    """this picks the most common genre, NOT the most relevant genre"""
    artist_info = spotify.artist(artist_id)
    list_of_genres = artist_info['genres']
    
    # default to alphabetically first genre from spotify
    most_common_genre = list_of_genres[0]
    if len(list_of_genres) == 1:
        pass
    else:
        for i, row in df_sorted_list_of_genres.iterrows():
            if row['genre_id'] in list_of_genres:
                return row['genre_id']
    return most_common_genre

# GENRE FUNCTION

def get_genre(track_id):
    """combines 2 helper functions, makes 2 queries to Spotify API"""
    artist_id = get_artist_id_by_track(track_id)
    return get_genre_by_artist(artist_id)

# %%
track_id = '7DZsH0df0GuULl0FGwXMfd'
get_genre(track_id)
# seems to work
# Out:
# 'jazz funk'

# %%
# TESTING

# %%
def get_artist_id(track_id):
    track_info = spotify.track(track_id)
    return track_info['artists'][0]['id']

track_id = '7DZsH0df0GuULl0FGwXMfd'
artist_id = get_artist_id(track_id)
artist_id

# %%
artist_id = '7izkpvBGc31hUccjdSNz8k'

def get_genre(artist_id):
    artist_info = spotify.artist(artist_id)
    list_of_genres = artist_info['genres']
    
    # default to alphabetically first genre from spotify
    most_common_genre = list_of_genres[0]
    if len(list_of_genres) == 1:
        pass
    else:
        for i, row in df_sorted_list_of_genres.iterrows():
            if row['genre_id'] in list_of_genres:
                return row['genre_id']
    return most_common_genre

genre_id = get_genre(artist_id)
genre_id
# Out:
# 'jazz funk'

# %%
artist_id = '7izkpvBGc31hUccjdSNz8k'
artist_info = spotify.artist(artist_id)
artist_info['genres']
# Out:
# ['instrumental soul', 'jazz funk', 'jazz organ', 'soul jazz']

# %%
df_B100_songs_AF.head()
# Out:
#                        id                                       song  \
# 0  7DZsH0df0GuULl0FGwXMfd                                      Misty
# 1  11Aldbvo6UCcVhBzv4oUdw                           What Now My Love
# 2  4KRLWRl1bFjnXhY5MgZWrM  May The Bird Of Paradise Fly Up Your Nose
# 3  5r96TaQquRrlo3Ym3ZlSL2                             Amish Paradise
# 4  1gloYGAZI6eHp6MEPjLuL3                             Canadian Idiot
#
#                    artist  acousticness  danceability  duration_ms  energy  \
# 0         "Groove" Holmes         0.806         0.581       360986   0.556
# 1         "Groove" Holmes         0.648         0.562       327560   0.573
# 2  "Little" Jimmy Dickens         0.738         0.660       151693   0.801
# 3     "Weird Al" Yankovic         0.103         0.728       202920   0.448
# 4     "Weird Al" Yankovic         0.002         0.543       143040   0.697
#
#    instrumentalness  key  liveness  loudness  mode  speechiness   tempo  \
# 0             0.925    8     0.218   -10.422     1        0.054  93.478
# 1             0.314    7     0.056   -10.972     1        0.034  91.845
# 2             0.000    4     0.627    -8.446     1        0.115 104.374
# 3             0.000    8     0.267   -10.540     1        0.172  80.902
# 4             0.000    8     0.343    -9.211     1        0.061 185.978
#
#    time_signature  valence release_date
# 0               4    0.313         1965
# 1               4    0.810   1965-01-01
# 2               4    0.867         1965
# 3               4    0.483   1996-12-31
# 4               4    0.861   2006-09-26

# %% [markdown]
# ### reorder dataframes and resave them

# %%
desired_formatting = [
    'id', 'song', 'artist', 'genre', 'release_date',
    'acousticness', 'danceability', 'duration_ms', 'energy', 
    'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 
    'speechiness', 'tempo', 'time_signature', 'valence'
]

# reorder
df_10M = df_10M[desired_formatting]
df_B100_songs = df_B100_songs[desired_formatting]

# save
