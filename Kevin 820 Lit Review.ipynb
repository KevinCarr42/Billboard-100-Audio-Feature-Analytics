# %%
import pandas as pd
import numpy as np

# jupyter notebook full-width display
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
filelocation = 'D:/RYERSON/820/2. Lit Review/rough work/'

# %%
# CSV files from https://elicit.org/
file1 = r'How do you cluster music based on audio features - elicit-results.csv'
file2 = r'How do you predict the popularity of music based on audio features - elicit-results.csv'
file3 = r'How do you recommend music based on audio features - elicit-results.csv'

dtypes = {'Citations': 'Int64'}

elicit_summary = pd.concat([
    pd.read_csv(filelocation + file1, dtype=dtypes),
    pd.read_csv(filelocation + file2, dtype=dtypes),
    pd.read_csv(filelocation + file3, dtype=dtypes)
]).reset_index(drop=True)

# summary of  paperdigest.org
paperdigest_summary = pd.read_csv(filelocation + 'paperdigest summary.csv')

# %%
elicit_summary.head()
# Out:
#                                          Paper title  \
# 0  A Clustering Analysis Method for Massive Music...
# 1  Music Personalized Label Clustering and Recomm...
# 2  Search Result Clustering in Collaborative Soun...
# 3  A music recommendation algorithm based on clus...
# 4  Comparing Audio Features and Playlist Statisti...
#
#                               Takeaway from abstract  \
# 0  Clustering analysis plays a very important rol...
# 1  Current recommendation systems require improve...
# 2  Clustering sound collections using audio featu...
# 3  Combining clustering and latent factor models ...
# 4  Comparing audio features and playlist statisti...
#
#                                              Authors  \
# 0                                 Yanping Xu, Sen Xu
# 1                                       Yongkang Huo
# 2                   Xavier Favory, F. Font, X. Serra
# 3                              Ying Jin, Chunyan Han
# ...

# %%
paperdigest_summary.head()
# Out:
#                                                Title  \
# 0                           Multimodal Deep Learning
# 1                End-to-end Learning for Music Audio
# 2  Determining Characteristics of Popular Local S...
# 3  Effect of Feature Selection on The Accuracy of...
# 4  Contextual Personalized Re-Ranking Of Music Re...
#
#                                              Authors  \
# 0  Jiquan Ngiam; Aditya Khosla; Mingyu Kim; Juhan...
# 1               Sander Dieleman; Benjamin Schrauwen;
# 2  Limisgy Ramadhina Febirautami; Isti Surjandari...
# 3  De Rosal Ignatius Moses Setiadi; Dewangga Satr...
# 4            Boning Gong; Mesut Kaya; Nava Tintarev;
#
#                                          Description  \
# 0  (Ngiam et. al., 2011) propose a novel applicat...
# 1  (Dieleman et. al., 2014) investigate whether i...
# 2  CART decision tree was conducted aiming to det...
# 3  (Setiadi et. al., 2020) aim to analyze the eff...
# ...
